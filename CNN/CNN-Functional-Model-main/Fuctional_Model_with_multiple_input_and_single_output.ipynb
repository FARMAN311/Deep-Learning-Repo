# %% [markdown]
# <a href="https://colab.research.google.com/github/FARMAN311/CNN-Functional-Model-API/blob/main/Fuctional_Model_with_multiple_input_and_single_output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow
from tensorflow import keras
from keras.layers import *
from keras.models import Model

# %%
input_1 = Input(shape=(32,))
input_2 = Input(shape=(128,))

# %%
x = Dense(8,activation='relu')(input_1)
x1 = Dense(16,activation='relu')(x)

# %%
y = Dense(64,activation='relu')(input_2)
y1 = Dense(32,activation='relu')(y)
y2 = Dense(4,activation='relu')(y1)

# %%
Combined = concatenate([x1,y2])

# %%
z = Dense(2,activation='relu')(Combined)
z1 = Dense(1,activation='linear')(z)

# %%
model = Model(inputs=[input_1,input_2], outputs=z1)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 128)            │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer (InputLayer)  │ (None, 32)             │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 64)             │          8,256 │ input_layer_1[0][0]    │
# ...

# %%
from keras.utils import plot_model
plot_model(model)
